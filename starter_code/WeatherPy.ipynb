# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\carlos\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\carlos\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=98d08ee6b90453f8454fd09764bdc2d2'

# %%
weather_response = requests.get(target_url)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "id": 524901,
#         "name": "Moscow",
#         "population": 0,
#         "sunrise": 1613106062,
#         "sunset": 1613140002,
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 95
#             },
#             "dt": 1613098800,
#             "dt_txt": "2021-02-12 03:00:00",
#             "main": {
#                 "feels_like": 251.54,
#                 "grnd_level": 998,
#                 "humidity": 86,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 258.36,
#                 "temp_kf": 0.19,
#                 "temp_max": 258.36,
#                 "temp_min": 258.17
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.44
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 135,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 36,
#                 "speed": 4.82
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1613109600,
#             "dt_txt": "2021-02-12 06:00:00",
#             "main": {
#                 "feels_like": 251.11,
#                 "grnd_level": 997,
#                 "humidity": 91,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 258.48,
#                 "temp_kf": 0.02,
#                 "temp_max": 258.48,
#                 "temp_min": 258.46
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.34
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 148,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13d",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 39,
#                 "speed": 5.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 99
#             },
#             "dt": 1613120400,
#             "dt_txt": "2021-02-12 09:00:00",
#             "main": {
#                 "feels_like": 251.57,
#                 "grnd_level": 996,
#                 "humidity": 94,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 259.47,
#                 "temp_kf": -0.06,
#                 "temp_max": 259.53,
#                 "temp_min": 259.47
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.37
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 140,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13d",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 32,
#                 "speed": 6.52
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613131200,
#             "dt_txt": "2021-02-12 12:00:00",
#             "main": {
#                 "feels_like": 251.8,
#                 "grnd_level": 995,
#                 "humidity": 95,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 260.1,
#                 "temp_kf": -0.01,
#                 "temp_max": 260.11,
#                 "temp_min": 260.1
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.44
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 142,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13d",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 35,
#                 "speed": 7.15
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613142000,
#             "dt_txt": "2021-02-12 15:00:00",
#             "main": {
#                 "feels_like": 251.19,
#                 "grnd_level": 994,
#                 "humidity": 94,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 259.62,
#                 "temp_kf": 0,
#                 "temp_max": 259.62,
#                 "temp_min": 259.62
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.56
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 145,
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13n",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 34,
#                 "speed": 7.28
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613152800,
#             "dt_txt": "2021-02-12 18:00:00",
#             "main": {
#                 "feels_like": 250.27,
#                 "grnd_level": 994,
#                 "humidity": 94,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 259.19,
#                 "temp_kf": 0,
#                 "temp_max": 259.19,
#                 "temp_min": 259.19
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.53
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 146,
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13n",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 35,
#                 "speed": 7.95
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613163600,
#             "dt_txt": "2021-02-12 21:00:00",
#             "main": {
#                 "feels_like": 249.69,
#                 "grnd_level": 992,
#                 "humidity": 94,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "temp": 258.85,
#                 "temp_kf": 0,
#                 "temp_max": 258.85,
#                 "temp_min": 258.85
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.96
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 132,
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13n",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 38,
#                 "speed": 8.27
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613174400,
#             "dt_txt": "2021-02-13 00:00:00",
#             "main": {
#                 "feels_like": 249.7,
#                 "grnd_level": 990,
#                 "humidity": 94,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 258.9,
#                 "temp_kf": 0,
#                 "temp_max": 258.9,
#                 "temp_min": 258.9
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 3.4
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 123,
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13n",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 41,
#                 "speed": 8.33
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613185200,
#             "dt_txt": "2021-02-13 03:00:00",
#             "main": {
#                 "feels_like": 249.33,
#                 "grnd_level": 986,
#                 "humidity": 94,
#                 "pressure": 1006,
#                 "sea_level": 1006,
#                 "temp": 258.76,
#                 "temp_kf": 0,
#                 "temp_max": 258.76,
#                 "temp_min": 258.76
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 4.27
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 131,
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13n",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 39,
#                 "speed": 8.64
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613196000,
#             "dt_txt": "2021-02-13 06:00:00",
#             "main": {
#                 "feels_like": 250.55,
#                 "grnd_level": 987,
#                 "humidity": 94,
#                 "pressure": 1006,
#                 "sea_level": 1006,
#                 "temp": 259.07,
#                 "temp_kf": 0,
#                 "temp_max": 259.07,
#                 "temp_min": 259.07
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.98
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 125,
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13d",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 44,
#                 "speed": 7.37
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613206800,
#             "dt_txt": "2021-02-13 09:00:00",
#             "main": {
#                 "feels_like": 253.14,
#                 "grnd_level": 987,
#                 "humidity": 95,
#                 "pressure": 1006,
#                 "sea_level": 1006,
#                 "temp": 260.65,
#                 "temp_kf": 0,
#                 "temp_max": 260.65,
#                 "temp_min": 260.65
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 1.69
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 225,
#             "weather": [
#                 {
#                     "description": "snow",
#                     "icon": "13d",
#                     "id": 601,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 49,
#                 "speed": 6.06
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613217600,
#             "dt_txt": "2021-02-13 12:00:00",
#             "main": {
#                 "feels_like": 255.06,
#                 "grnd_level": 988,
#                 "humidity": 95,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "temp": 261.68,
#                 "temp_kf": 0,
#                 "temp_max": 261.68,
#                 "temp_min": 261.68
#             },
#             "pop": 1,
#             "snow": {
#                 "3h": 0.38
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 351,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13d",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 49,
#                 "speed": 4.88
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613228400,
#             "dt_txt": "2021-02-13 15:00:00",
#             "main": {
#                 "feels_like": 253.67,
#                 "grnd_level": 987,
#                 "humidity": 95,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "temp": 259.69,
#                 "temp_kf": 0,
#                 "temp_max": 259.69,
#                 "temp_min": 259.69
#             },
#             "pop": 0.74,
#             "snow": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 524,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 27,
#                 "speed": 3.85
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613239200,
#             "dt_txt": "2021-02-13 18:00:00",
#             "main": {
#                 "feels_like": 252.37,
#                 "grnd_level": 988,
#                 "humidity": 94,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "temp": 258.82,
#                 "temp_kf": 0,
#                 "temp_max": 258.82,
#                 "temp_min": 258.82
#             },
#             "pop": 0.66,
#             "snow": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 574,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 15,
#                 "speed": 4.39
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613250000,
#             "dt_txt": "2021-02-13 21:00:00",
#             "main": {
#                 "feels_like": 251.64,
#                 "grnd_level": 988,
#                 "humidity": 94,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "temp": 257.91,
#                 "temp_kf": 0,
#                 "temp_max": 257.91,
#                 "temp_min": 257.91
#             },
#             "pop": 0.38,
#             "snow": {
#                 "3h": 0.19
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 510,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 18,
#                 "speed": 4.07
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613260800,
#             "dt_txt": "2021-02-14 00:00:00",
#             "main": {
#                 "feels_like": 251.21,
#                 "grnd_level": 988,
#                 "humidity": 94,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "temp": 256.94,
#                 "temp_kf": 0,
#                 "temp_max": 256.94,
#                 "temp_min": 256.94
#             },
#             "pop": 0.38,
#             "snow": {
#                 "3h": 0.19
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 451,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 1,
#                 "speed": 3.24
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613271600,
#             "dt_txt": "2021-02-14 03:00:00",
#             "main": {
#                 "feels_like": 250.72,
#                 "grnd_level": 988,
#                 "humidity": 93,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "temp": 256.76,
#                 "temp_kf": 0,
#                 "temp_max": 256.76,
#                 "temp_min": 256.76
#             },
#             "pop": 0.2,
#             "snow": {
#                 "3h": 0.25
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 563,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 347,
#                 "speed": 3.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613282400,
#             "dt_txt": "2021-02-14 06:00:00",
#             "main": {
#                 "feels_like": 251.23,
#                 "grnd_level": 990,
#                 "humidity": 93,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "temp": 257.42,
#                 "temp_kf": 0,
#                 "temp_max": 257.42,
#                 "temp_min": 257.42
#             },
#             "pop": 0.06,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 833,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 340,
#                 "speed": 3.92
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613293200,
#             "dt_txt": "2021-02-14 09:00:00",
#             "main": {
#                 "feels_like": 252.76,
#                 "grnd_level": 991,
#                 "humidity": 93,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "temp": 259.51,
#                 "temp_kf": 0,
#                 "temp_max": 259.51,
#                 "temp_min": 259.51
#             },
#             "pop": 0.32,
#             "snow": {
#                 "3h": 0.16
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 1070,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13d",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 339,
#                 "speed": 4.86
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613304000,
#             "dt_txt": "2021-02-14 12:00:00",
#             "main": {
#                 "feels_like": 252.75,
#                 "grnd_level": 993,
#                 "humidity": 93,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 259.62,
#                 "temp_kf": 0,
#                 "temp_max": 259.62,
#                 "temp_min": 259.62
#             },
#             "pop": 0.3,
#             "snow": {
#                 "3h": 0.19
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 1060,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13d",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 330,
#                 "speed": 5.04
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613314800,
#             "dt_txt": "2021-02-14 15:00:00",
#             "main": {
#                 "feels_like": 252.64,
#                 "grnd_level": 994,
#                 "humidity": 93,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 258.73,
#                 "temp_kf": 0,
#                 "temp_max": 258.73,
#                 "temp_min": 258.73
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 4486,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 323,
#                 "speed": 3.86
#             }
#         },
#         {
#             "clouds": {
#                 "all": 99
#             },
#             "dt": 1613325600,
#             "dt_txt": "2021-02-14 18:00:00",
#             "main": {
#                 "feels_like": 250.88,
#                 "grnd_level": 997,
#                 "humidity": 92,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 256.66,
#                 "temp_kf": 0,
#                 "temp_max": 256.66,
#                 "temp_min": 256.66
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 314,
#                 "speed": 3.28
#             }
#         },
#         {
#             "clouds": {
#                 "all": 57
#             },
#             "dt": 1613336400,
#             "dt_txt": "2021-02-14 21:00:00",
#             "main": {
#                 "feels_like": 247.39,
#                 "grnd_level": 998,
#                 "humidity": 91,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 253.14,
#                 "temp_kf": 0,
#                 "temp_max": 253.14,
#                 "temp_min": 253.14
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 313,
#                 "speed": 3.03
#             }
#         },
#         {
#             "clouds": {
#                 "all": 29
#             },
#             "dt": 1613347200,
#             "dt_txt": "2021-02-15 00:00:00",
#             "main": {
#                 "feels_like": 244.89,
#                 "grnd_level": 1001,
#                 "humidity": 90,
#                 "pressure": 1021,
#                 "sea_level": 1021,
#                 "temp": 250.55,
#                 "temp_kf": 0,
#                 "temp_max": 250.55,
#                 "temp_min": 250.55
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 314,
#                 "speed": 2.8
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1613358000,
#             "dt_txt": "2021-02-15 03:00:00",
#             "main": {
#                 "feels_like": 242.81,
#                 "grnd_level": 1001,
#                 "humidity": 89,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "temp": 248.4,
#                 "temp_kf": 0,
#                 "temp_max": 248.4,
#                 "temp_min": 248.4
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 316,
#                 "speed": 2.62
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1613368800,
#             "dt_txt": "2021-02-15 06:00:00",
#             "main": {
#                 "feels_like": 242.17,
#                 "grnd_level": 1003,
#                 "humidity": 88,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "temp": 247.54,
#                 "temp_kf": 0,
#                 "temp_max": 247.54,
#                 "temp_min": 247.54
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 324,
#                 "speed": 2.27
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1613379600,
#             "dt_txt": "2021-02-15 09:00:00",
#             "main": {
#                 "feels_like": 247.58,
#                 "grnd_level": 1005,
#                 "humidity": 90,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "temp": 252.98,
#                 "temp_kf": 0,
#                 "temp_max": 252.98,
#                 "temp_min": 252.98
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 337,
#                 "speed": 2.52
#             }
#         },
#         {
#             "clouds": {
#                 "all": 12
#             },
#             "dt": 1613390400,
#             "dt_txt": "2021-02-15 12:00:00",
#             "main": {
#                 "feels_like": 249.78,
#                 "grnd_level": 1006,
#                 "humidity": 91,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "temp": 255.32,
#                 "temp_kf": 0,
#                 "temp_max": 255.32,
#                 "temp_min": 255.32
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 338,
#                 "speed": 2.84
#             }
#         },
#         {
#             "clouds": {
#                 "all": 45
#             },
#             "dt": 1613401200,
#             "dt_txt": "2021-02-15 15:00:00",
#             "main": {
#                 "feels_like": 245.36,
#                 "grnd_level": 1007,
#                 "humidity": 90,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 250.73,
#                 "temp_kf": 0,
#                 "temp_max": 250.73,
#                 "temp_min": 250.73
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 336,
#                 "speed": 2.38
#             }
#         },
#         {
#             "clouds": {
#                 "all": 46
#             },
#             "dt": 1613412000,
#             "dt_txt": "2021-02-15 18:00:00",
#             "main": {
#                 "feels_like": 242.73,
#                 "grnd_level": 1008,
#                 "humidity": 89,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "temp": 247.89,
#                 "temp_kf": 0,
#                 "temp_max": 247.89,
#                 "temp_min": 247.89
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 332,
#                 "speed": 1.99
#             }
#         },
#         {
#             "clouds": {
#                 "all": 13
#             },
#             "dt": 1613422800,
#             "dt_txt": "2021-02-15 21:00:00",
#             "main": {
#                 "feels_like": 241.74,
#                 "grnd_level": 1008,
#                 "humidity": 88,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "temp": 246.7,
#                 "temp_kf": 0,
#                 "temp_max": 246.7,
#                 "temp_min": 246.7
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 312,
#                 "speed": 1.66
#             }
#         },
#         {
#             "clouds": {
#                 "all": 6
#             },
#             "dt": 1613433600,
#             "dt_txt": "2021-02-16 00:00:00",
#             "main": {
#                 "feels_like": 241.3,
#                 "grnd_level": 1009,
#                 "humidity": 87,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "temp": 246.19,
#                 "temp_kf": 0,
#                 "temp_max": 246.19,
#                 "temp_min": 246.19
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 273,
#                 "speed": 1.54
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1613444400,
#             "dt_txt": "2021-02-16 03:00:00",
#             "main": {
#                 "feels_like": 240.96,
#                 "grnd_level": 1007,
#                 "humidity": 86,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "temp": 246.3,
#                 "temp_kf": 0,
#                 "temp_max": 246.3,
#                 "temp_min": 246.3
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 252,
#                 "speed": 2.19
#             }
#         },
#         {
#             "clouds": {
#                 "all": 1
#             },
#             "dt": 1613455200,
#             "dt_txt": "2021-02-16 06:00:00",
#             "main": {
#                 "feels_like": 242.08,
#                 "grnd_level": 1007,
#                 "humidity": 87,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "temp": 247.65,
#                 "temp_kf": 0,
#                 "temp_max": 247.65,
#                 "temp_min": 247.65
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 228,
#                 "speed": 2.56
#             }
#         },
#         {
#             "clouds": {
#                 "all": 56
#             },
#             "dt": 1613466000,
#             "dt_txt": "2021-02-16 09:00:00",
#             "main": {
#                 "feels_like": 248.73,
#                 "grnd_level": 1006,
#                 "humidity": 89,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "temp": 254.69,
#                 "temp_kf": 0,
#                 "temp_max": 254.69,
#                 "temp_min": 254.69
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 215,
#                 "speed": 3.4
#             }
#         },
#         {
#             "clouds": {
#                 "all": 59
#             },
#             "dt": 1613476800,
#             "dt_txt": "2021-02-16 12:00:00",
#             "main": {
#                 "feels_like": 251.34,
#                 "grnd_level": 1004,
#                 "humidity": 92,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "temp": 257.32,
#                 "temp_kf": 0,
#                 "temp_max": 257.32,
#                 "temp_min": 257.32
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 227,
#                 "speed": 3.6
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1613487600,
#             "dt_txt": "2021-02-16 15:00:00",
#             "main": {
#                 "feels_like": 249.86,
#                 "grnd_level": 1003,
#                 "humidity": 93,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 255.3,
#                 "temp_kf": 0,
#                 "temp_max": 255.3,
#                 "temp_min": 255.3
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 886,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 229,
#                 "speed": 2.71
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613498400,
#             "dt_txt": "2021-02-16 18:00:00",
#             "main": {
#                 "feels_like": 250.59,
#                 "grnd_level": 1003,
#                 "humidity": 93,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 255.65,
#                 "temp_kf": 0,
#                 "temp_max": 255.65,
#                 "temp_min": 255.65
#             },
#             "pop": 0.2,
#             "snow": {
#                 "3h": 0.15
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 1280,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 230,
#                 "speed": 2.19
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613509200,
#             "dt_txt": "2021-02-16 21:00:00",
#             "main": {
#                 "feels_like": 250.97,
#                 "grnd_level": 1003,
#                 "humidity": 93,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 255.53,
#                 "temp_kf": 0,
#                 "temp_max": 255.53,
#                 "temp_min": 255.53
#             },
#             "pop": 0.24,
#             "snow": {
#                 "3h": 0.16
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 784,
#             "weather": [
#                 {
#                     "description": "light snow",
#                     "icon": "13n",
#                     "id": 600,
#                     "main": "Snow"
#                 }
#             ],
#             "wind": {
#                 "deg": 245,
#                 "speed": 1.47
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1613520000,
#             "dt_txt": "2021-02-17 00:00:00",
#             "main": {
#                 "feels_like": 250.7,
#                 "grnd_level": 1003,
#                 "humidity": 93,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "temp": 254.98,
#                 "temp_kf": 0,
#                 "temp_max": 254.98,
#                 "temp_min": 254.98
#             },
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "visibility": 1452,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 357,
#                 "speed": 1.04
#             }
#         }
#     ],
#     "message": 0
# }

# %%
print(weather_json['city']['name'])
# Out:
# Moscow

# %%
# set up lists to hold reponse info
cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

#  response = requests.get(query_url + city).json()
    
# Loop through the list of cities and perform a request for data on each

for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("Record not found") 
        pass
        
print("I made it through the gauntlet. The message survived!")
# Out:
# Processing record 1 of Set 1 | marsa matruh
# Processing record 2 of Set 1 | kuching
# Processing record 3 of Set 1 | ushuaia
# Processing record 4 of Set 1 | natalinsk
# Processing record 5 of Set 1 | szczecin
# Processing record 6 of Set 1 | lincoln
# Processing record 7 of Set 1 | necochea
# Processing record 8 of Set 1 | kodiak
# Processing record 9 of Set 1 | henties bay
# Record not found
# Processing record 10 of Set 1 | butaritari
# Processing record 11 of Set 1 | kapaa
# Processing record 12 of Set 1 | jamestown
# Processing record 13 of Set 1 | mar del plata
# Processing record 14 of Set 1 | faanui
# Processing record 15 of Set 1 | mosquera
# Record not found
# Processing record 16 of Set 1 | qaanaaq
# Processing record 17 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 18 of Set 1 | norsup
# Record not found
# Processing record 19 of Set 1 | mataura
# Processing record 20 of Set 1 | nikolskoye
# Processing record 21 of Set 1 | cape town
# Processing record 22 of Set 1 | padang
# Processing record 23 of Set 1 | avarua
# Processing record 24 of Set 1 | talnakh
# Processing record 25 of Set 1 | floresti
# Processing record 26 of Set 1 | great bend
# Processing record 27 of Set 1 | hobart
# Processing record 28 of Set 1 | punta arenas
# Processing record 29 of Set 1 | geraldton
# Record not found
# Processing record 30 of Set 1 | turukhansk
# Processing record 31 of Set 1 | sitka
# Processing record 32 of Set 1 | cap malheureux
# Processing record 33 of Set 1 | bluff
# Record not found
# Processing record 34 of Set 1 | tasiilaq
# Processing record 35 of Set 1 | russell
# Processing record 36 of Set 1 | dunedin
# Processing record 37 of Set 1 | rikitea
# Processing record 38 of Set 1 | albany
# Processing record 39 of Set 1 | tiksi
# Processing record 40 of Set 1 | rio grande
# Processing record 41 of Set 1 | mandalgovi
# Processing record 42 of Set 1 | laguna
# Processing record 43 of Set 1 | hilo
# Processing record 44 of Set 1 | hermanus
# Processing record 45 of Set 1 | wukari
# Processing record 46 of Set 1 | husavik
# Processing record 47 of Set 1 | kununurra
# Processing record 48 of Set 1 | chandler
# Processing record 49 of Set 1 | salalah
# Record not found
# Processing record 50 of Set 1 | luxor
# Processing record 51 of Set 1 | bengkulu
# Processing record 52 of Set 1 | regeneracao
# Processing record 53 of Set 1 | lodja
# Processing record 54 of Set 1 | kismayo
# Processing record 55 of Set 1 | guhagar
# Processing record 56 of Set 1 | kruisfontein
# Processing record 57 of Set 1 | bakel
# Processing record 58 of Set 1 | atuona
# Processing record 59 of Set 1 | cidreira
# Processing record 60 of Set 1 | aykhal
# Record not found
# Processing record 61 of Set 1 | carnarvon
# Processing record 62 of Set 1 | lebu
# Processing record 63 of Set 1 | new norfolk
# Processing record 64 of Set 1 | atambua
# Processing record 65 of Set 1 | diamantino
# Record not found
# Processing record 66 of Set 1 | nome
# Processing record 67 of Set 1 | souillac
# Processing record 68 of Set 1 | bafq
# Processing record 69 of Set 1 | vredendal
# Processing record 70 of Set 1 | port alfred
# Processing record 71 of Set 1 | walvis bay
# Processing record 72 of Set 1 | vestmannaeyjar
# Processing record 73 of Set 1 | bambous virieux
# Processing record 74 of Set 1 | katsuura
# Record not found
# Processing record 75 of Set 1 | galle
# Processing record 76 of Set 1 | vaini
# Processing record 77 of Set 1 | khatanga
# Processing record 78 of Set 1 | bandarbeyla
# Processing record 79 of Set 1 | novikovo
# Processing record 80 of Set 1 | batemans bay
# Processing record 81 of Set 1 | puerto ayora
# Processing record 82 of Set 1 | saint-philippe
# Processing record 83 of Set 1 | san alberto
# Processing record 84 of Set 1 | neftcala
# Processing record 85 of Set 1 | biak
# Processing record 86 of Set 1 | junin
# Record not found
# Processing record 87 of Set 1 | yatou
# Processing record 88 of Set 1 | chokurdakh
# Processing record 89 of Set 1 | berlevag
# Processing record 90 of Set 1 | phalaborwa
# Processing record 91 of Set 1 | korla
# Processing record 92 of Set 1 | manggar
# Processing record 93 of Set 1 | weligama
# Processing record 94 of Set 1 | tessalit
# Processing record 95 of Set 1 | port blair
# Processing record 96 of Set 1 | barrow
# Processing record 97 of Set 1 | brownwood
# Processing record 98 of Set 1 | cayenne
# Processing record 99 of Set 1 | busselton
# Processing record 100 of Set 1 | saint george
# Processing record 101 of Set 1 | cherskiy
# Processing record 102 of Set 1 | ucluelet
# Processing record 103 of Set 1 | banda aceh
# Processing record 104 of Set 1 | puerto baquerizo moreno
# Processing record 105 of Set 1 | esperance
# Processing record 106 of Set 1 | tuatapere
# Processing record 107 of Set 1 | lata
# Processing record 108 of Set 1 | severo-kurilsk
# Processing record 109 of Set 1 | qaqortoq
# Processing record 110 of Set 1 | waddan
# Processing record 111 of Set 1 | los llanos de aridane
# Processing record 112 of Set 1 | sao filipe
# Record not found
# Record not found
# Processing record 113 of Set 1 | hualmay
# Processing record 114 of Set 1 | honningsvag
# Processing record 115 of Set 1 | juba
# Processing record 116 of Set 1 | praia da vitoria
# Processing record 117 of Set 1 | moctezuma
# Processing record 118 of Set 1 | la ronge
# Processing record 119 of Set 1 | atar
# Processing record 120 of Set 1 | cancun
# Processing record 121 of Set 1 | nanortalik
# Processing record 122 of Set 1 | port hardy
# Processing record 123 of Set 1 | naze
# Record not found
# Processing record 124 of Set 1 | oda
# Processing record 125 of Set 1 | fortuna
# Processing record 126 of Set 1 | port augusta
# Processing record 127 of Set 1 | kaitangata
# Processing record 128 of Set 1 | bredasdorp
# Processing record 129 of Set 1 | omsukchan
# Processing record 130 of Set 1 | rolla
# Processing record 131 of Set 1 | hovd
# Processing record 132 of Set 1 | dikson
# Processing record 133 of Set 1 | nador
# Record not found
# Processing record 134 of Set 1 | maragogi
# Processing record 135 of Set 1 | ailigandi
# Processing record 136 of Set 1 | grants
# Processing record 137 of Set 1 | pevek
# Processing record 138 of Set 1 | awjilah
# Processing record 139 of Set 1 | morro bay
# Processing record 140 of Set 1 | oliver
# Processing record 141 of Set 1 | airai
# Processing record 142 of Set 1 | yellowknife
# Processing record 143 of Set 1 | gandu
# Processing record 144 of Set 1 | norman wells
# Processing record 145 of Set 1 | aitape
# Processing record 146 of Set 1 | bogorodskoye
# Processing record 147 of Set 1 | zhangjiakou
# Processing record 148 of Set 1 | ribeira grande
# Processing record 149 of Set 1 | vanimo
# Record not found
# Processing record 150 of Set 1 | takaka
# Processing record 151 of Set 1 | nagato
# Processing record 152 of Set 1 | karratha
# Processing record 153 of Set 1 | hasaki
# Record not found
# Processing record 154 of Set 1 | fairbanks
# Processing record 155 of Set 1 | vila velha
# Processing record 156 of Set 1 | sayansk
# Processing record 157 of Set 1 | lavrentiya
# Processing record 158 of Set 1 | east london
# Processing record 159 of Set 1 | narasannapeta
# Processing record 160 of Set 1 | tinos
# Record not found
# Processing record 161 of Set 1 | san cristobal
# Processing record 162 of Set 1 | constitucion
# Processing record 163 of Set 1 | worthing
# Processing record 164 of Set 1 | mehamn
# Processing record 165 of Set 1 | margate
# Processing record 166 of Set 1 | camacha
# Processing record 167 of Set 1 | eenhana
# Processing record 168 of Set 1 | chumikan
# Processing record 169 of Set 1 | ukiah
# Processing record 170 of Set 1 | warmbad
# Processing record 171 of Set 1 | severnyy
# Processing record 172 of Set 1 | tarata
# Processing record 173 of Set 1 | vavuniya
# Processing record 174 of Set 1 | hobyo
# Processing record 175 of Set 1 | tuktoyaktuk
# Record not found
# Processing record 176 of Set 1 | miri
# Processing record 177 of Set 1 | deputatskiy
# Processing record 178 of Set 1 | alofi
# Processing record 179 of Set 1 | upernavik
# Processing record 180 of Set 1 | srednekolymsk
# Record not found
# Processing record 181 of Set 1 | champerico
# Record not found
# Processing record 182 of Set 1 | rawson
# Processing record 183 of Set 1 | deep river
# Processing record 184 of Set 1 | charlestown
# Processing record 185 of Set 1 | westport
# Processing record 186 of Set 1 | ambilobe
# Processing record 187 of Set 1 | muscatine
# Processing record 188 of Set 1 | okhotsk
# Processing record 189 of Set 1 | ekhabi
# Processing record 190 of Set 1 | remontnoye
# Processing record 191 of Set 1 | roma
# Processing record 192 of Set 1 | trinidad
# Processing record 193 of Set 1 | gat
# Processing record 194 of Set 1 | ancud
# Processing record 195 of Set 1 | rincon
# Processing record 196 of Set 1 | gazojak
# Processing record 197 of Set 1 | avera
# Processing record 198 of Set 1 | cuamba
# Processing record 199 of Set 1 | borogontsy
# Processing record 200 of Set 1 | rochegda
# Record not found
# Processing record 201 of Set 1 | takoradi
# Processing record 202 of Set 1 | shumerlya
# Processing record 203 of Set 1 | enshi
# Processing record 204 of Set 1 | kavieng
# Processing record 205 of Set 1 | bethel
# Processing record 206 of Set 1 | mirpur khas
# Record not found
# Record not found
# Processing record 207 of Set 1 | balkanabat
# Processing record 208 of Set 1 | teya
# Processing record 209 of Set 1 | nabire
# Processing record 210 of Set 1 | tilichiki
# Processing record 211 of Set 1 | portland
# Processing record 212 of Set 1 | castro
# Processing record 213 of Set 1 | san rafael
# Processing record 214 of Set 1 | kloulklubed
# Processing record 215 of Set 1 | carauari
# Processing record 216 of Set 1 | verkh-suetka
# Processing record 217 of Set 1 | rondonopolis
# Processing record 218 of Set 1 | ranau
# Processing record 219 of Set 1 | obo
# Processing record 220 of Set 1 | vendome
# Processing record 221 of Set 1 | kabalo
# Record not found
# Processing record 222 of Set 1 | chicama
# Processing record 223 of Set 1 | byron bay
# Record not found
# Processing record 224 of Set 1 | encheng
# Processing record 225 of Set 1 | payson
# Processing record 226 of Set 1 | iqaluit
# Processing record 227 of Set 1 | imeni zhelyabova
# Record not found
# Processing record 228 of Set 1 | san quintin
# Processing record 229 of Set 1 | harper
# Processing record 230 of Set 1 | pochutla
# Processing record 231 of Set 1 | oistins
# Processing record 232 of Set 1 | verkhnyaya toyma
# Processing record 233 of Set 1 | saskylakh
# Processing record 234 of Set 1 | rio gallegos
# Processing record 235 of Set 1 | alekseyevsk
# Processing record 236 of Set 1 | nizwa
# Processing record 237 of Set 1 | valle hermoso
# Processing record 238 of Set 1 | umm kaddadah
# Processing record 239 of Set 1 | makakilo city
# Processing record 240 of Set 1 | qianan
# Processing record 241 of Set 1 | bilibino
# Processing record 242 of Set 1 | labuhan
# Processing record 243 of Set 1 | darab
# Processing record 244 of Set 1 | seddon
# Processing record 245 of Set 1 | roald
# Processing record 246 of Set 1 | provideniya
# Processing record 247 of Set 1 | agutaya
# Processing record 248 of Set 1 | lima
# Record not found
# Record not found
# Processing record 249 of Set 1 | bubaque
# Processing record 250 of Set 1 | pangody
# Processing record 251 of Set 1 | georgetown
# Processing record 252 of Set 1 | rundu
# Processing record 253 of Set 1 | cabedelo
# Processing record 254 of Set 1 | vila franca do campo
# Processing record 255 of Set 1 | carballo
# Processing record 256 of Set 1 | ixtapa
# Processing record 257 of Set 1 | antofagasta
# Processing record 258 of Set 1 | saint-francois
# Processing record 259 of Set 1 | ziarat
# Record not found
# Processing record 260 of Set 1 | khandyga
# Processing record 261 of Set 1 | njeru
# Processing record 262 of Set 1 | formosa
# Record not found
# Processing record 263 of Set 1 | xining
# Processing record 264 of Set 1 | komsomolskiy
# Processing record 265 of Set 1 | mago
# Processing record 266 of Set 1 | klaksvik
# Processing record 267 of Set 1 | imeni poliny osipenko
# Processing record 268 of Set 1 | broome
# Processing record 269 of Set 1 | mvuma
# Processing record 270 of Set 1 | san policarpo
# Record not found
# Processing record 271 of Set 1 | marrakesh
# Processing record 272 of Set 1 | chapleau
# Processing record 273 of Set 1 | ponta do sol
# Processing record 274 of Set 1 | paamiut
# Processing record 275 of Set 1 | olga
# Processing record 276 of Set 1 | isangel
# Processing record 277 of Set 1 | igunga
# Processing record 278 of Set 1 | pisco
# Processing record 279 of Set 1 | narsaq
# Processing record 280 of Set 1 | olafsvik
# Processing record 281 of Set 1 | hithadhoo
# Processing record 282 of Set 1 | haines junction
# Processing record 283 of Set 1 | victoria
# Processing record 284 of Set 1 | yarkovo
# Processing record 285 of Set 1 | kulhudhuffushi
# Processing record 286 of Set 1 | aklavik
# Processing record 287 of Set 1 | zambezi
# Processing record 288 of Set 1 | bonavista
# Processing record 289 of Set 1 | kaduqli
# Processing record 290 of Set 1 | sistranda
# Processing record 291 of Set 1 | port elizabeth
# Processing record 292 of Set 1 | solone
# Processing record 293 of Set 1 | san patricio
# Processing record 294 of Set 1 | myaundzha
# Processing record 295 of Set 1 | lom sak
# Processing record 296 of Set 1 | padrauna
# Processing record 297 of Set 1 | kars
# Processing record 298 of Set 1 | moree
# Processing record 299 of Set 1 | manokwari
# Processing record 300 of Set 1 | waipawa
# Processing record 301 of Set 1 | teahupoo
# Processing record 302 of Set 1 | etampes
# Processing record 303 of Set 1 | dolinsk
# Processing record 304 of Set 1 | port lincoln
# Processing record 305 of Set 1 | karsava
# Processing record 306 of Set 1 | clarence town
# Processing record 307 of Set 1 | lensk
# Processing record 308 of Set 1 | kitimat
# Processing record 309 of Set 1 | nortelandia
# Processing record 310 of Set 1 | beringovskiy
# Processing record 311 of Set 1 | zhigansk
# Processing record 312 of Set 1 | vanino
# Processing record 313 of Set 1 | benguela
# Processing record 314 of Set 1 | nishihara
# Processing record 315 of Set 1 | namatanai
# Processing record 316 of Set 1 | bemidji
# Processing record 317 of Set 1 | sur
# Processing record 318 of Set 1 | seydi
# Processing record 319 of Set 1 | hanzhong
# Processing record 320 of Set 1 | north myrtle beach
# Processing record 321 of Set 1 | baruun-urt
# Processing record 322 of Set 1 | cockburn town
# Record not found
# Processing record 323 of Set 1 | krasnoselkup
# Processing record 324 of Set 1 | clyde river
# Processing record 325 of Set 1 | le port
# Processing record 326 of Set 1 | luderitz
# Processing record 327 of Set 1 | ilulissat
# Processing record 328 of Set 1 | port hedland
# Processing record 329 of Set 1 | verkh-usugli
# Processing record 330 of Set 1 | te anau
# Processing record 331 of Set 1 | torbay
# Processing record 332 of Set 1 | najran
# Processing record 333 of Set 1 | bam
# Processing record 334 of Set 1 | yumen
# Processing record 335 of Set 1 | manakara
# Processing record 336 of Set 1 | jacareacanga
# Processing record 337 of Set 1 | luba
# Processing record 338 of Set 1 | sagua la grande
# Processing record 339 of Set 1 | mafeteng
# Processing record 340 of Set 1 | oksfjord
# Processing record 341 of Set 1 | miraflores
# Processing record 342 of Set 1 | camopi
# Processing record 343 of Set 1 | yulara
# Processing record 344 of Set 1 | kasongo-lunda
# Processing record 345 of Set 1 | arraial do cabo
# Processing record 346 of Set 1 | carlisle
# Processing record 347 of Set 1 | itarema
# Processing record 348 of Set 1 | wailuku
# Processing record 349 of Set 1 | inta
# Processing record 350 of Set 1 | thyboron
# Processing record 351 of Set 1 | flinders
# Processing record 352 of Set 1 | taoudenni
# Processing record 353 of Set 1 | yakeshi
# Processing record 354 of Set 1 | thunder bay
# Processing record 355 of Set 1 | neepawa
# Processing record 356 of Set 1 | shingu
# Processing record 357 of Set 1 | buraydah
# Processing record 358 of Set 1 | boende
# Processing record 359 of Set 1 | inuvik
# Processing record 360 of Set 1 | riyadh
# Processing record 361 of Set 1 | yerbogachen
# Processing record 362 of Set 1 | codrington
# Processing record 363 of Set 1 | sydney
# Processing record 364 of Set 1 | ahuimanu
# Record not found
# Processing record 365 of Set 1 | brae
# Processing record 366 of Set 1 | verkhnyaya inta
# Processing record 367 of Set 1 | leningradskiy
# Processing record 368 of Set 1 | shelburne
# Processing record 369 of Set 1 | saldanha
# Processing record 370 of Set 1 | zhumadian
# Processing record 371 of Set 1 | ribeira do pombal
# Processing record 372 of Set 1 | teguise
# Processing record 373 of Set 1 | kahului
# Processing record 374 of Set 1 | mujiayingzi
# Processing record 375 of Set 1 | thompson
# Processing record 376 of Set 1 | atyrau
# Processing record 377 of Set 1 | kasangulu
# Processing record 378 of Set 1 | gimli
# Processing record 379 of Set 1 | poya
# Processing record 380 of Set 1 | puerto leguizamo
# Processing record 381 of Set 1 | sarankhola
# Processing record 382 of Set 1 | darhan
# Record not found
# Processing record 383 of Set 1 | dingle
# Processing record 384 of Set 1 | sinjar
# Processing record 385 of Set 1 | saqqez
# Processing record 386 of Set 1 | adrar
# Processing record 387 of Set 1 | raga
# Processing record 388 of Set 1 | manavgat
# Processing record 389 of Set 1 | mersing
# Processing record 390 of Set 1 | nemuro
# Processing record 391 of Set 1 | puerto escondido
# Processing record 392 of Set 1 | araouane
# Processing record 393 of Set 1 | moron
# Processing record 394 of Set 1 | bardiyah
# Processing record 395 of Set 1 | yuzhnouralsk
# Processing record 396 of Set 1 | havelock
# Processing record 397 of Set 1 | isla vista
# Processing record 398 of Set 1 | torrington
# Processing record 399 of Set 1 | nesna
# Record not found
# Processing record 400 of Set 1 | grindavik
# Processing record 401 of Set 1 | abatskoye
# Processing record 402 of Set 1 | bulawayo
# Processing record 403 of Set 1 | yinchuan
# Processing record 404 of Set 1 | ugoofaaru
# Processing record 405 of Set 1 | kalmunai
# Processing record 406 of Set 1 | heishan
# Record not found
# Processing record 407 of Set 1 | bila tserkva
# Processing record 408 of Set 1 | teplyk
# Processing record 409 of Set 1 | ouadda
# Processing record 410 of Set 1 | wanaka
# Processing record 411 of Set 1 | kamen-na-obi
# Processing record 412 of Set 1 | obzor
# Processing record 413 of Set 1 | gambela
# Processing record 414 of Set 1 | hay river
# Processing record 415 of Set 1 | huai yot
# Processing record 416 of Set 1 | bridgton
# Processing record 417 of Set 1 | monywa
# Processing record 418 of Set 1 | san francisco menendez
# Processing record 419 of Set 1 | comodoro rivadavia
# Processing record 420 of Set 1 | kharan
# Processing record 421 of Set 1 | gonbad-e qabus
# Processing record 422 of Set 1 | tonantins
# Processing record 423 of Set 1 | vardo
# Processing record 424 of Set 1 | itaituba
# Processing record 425 of Set 1 | ourossogui
# Processing record 426 of Set 1 | khani
# Processing record 427 of Set 1 | sukhobuzimskoye
# Processing record 428 of Set 1 | ongandjera
# Processing record 429 of Set 1 | siniscola
# Processing record 430 of Set 1 | mayo
# Record not found
# Processing record 431 of Set 1 | sao joao da barra
# Processing record 432 of Set 1 | seoul
# Processing record 433 of Set 1 | meulaboh
# Processing record 434 of Set 1 | buala
# Processing record 435 of Set 1 | manzil kamil
# Processing record 436 of Set 1 | san pedro de macoris
# Processing record 437 of Set 1 | nieuw amsterdam
# Processing record 438 of Set 1 | slave lake
# Processing record 439 of Set 1 | wasilla
# Processing record 440 of Set 1 | matara
# Processing record 441 of Set 1 | villablino
# Processing record 442 of Set 1 | nyurba
# Processing record 443 of Set 1 | yanaul
# Processing record 444 of Set 1 | asyut
# Processing record 445 of Set 1 | baykit
# Record not found
# Processing record 446 of Set 1 | conceicao da barra
# Processing record 447 of Set 1 | alliston
# Processing record 448 of Set 1 | tautira
# Processing record 449 of Set 1 | kailua
# Processing record 450 of Set 1 | coquimbo
# Processing record 451 of Set 1 | wewak
# Processing record 452 of Set 1 | richards bay
# Processing record 453 of Set 1 | egvekinot
# Processing record 454 of Set 1 | sabya
# Processing record 455 of Set 1 | kolno
# Processing record 456 of Set 1 | male
# Processing record 457 of Set 1 | urumqi
# Record not found
# Processing record 458 of Set 1 | asau
# Processing record 459 of Set 1 | guca
# Processing record 460 of Set 1 | ostrovnoy
# Processing record 461 of Set 1 | bikramganj
# Processing record 462 of Set 1 | villazon
# Processing record 463 of Set 1 | radchenko
# Processing record 464 of Set 1 | torquay
# Processing record 465 of Set 1 | port macquarie
# Processing record 466 of Set 1 | pemba
# Processing record 467 of Set 1 | urbano santos
# Processing record 468 of Set 1 | morondava
# Processing record 469 of Set 1 | palmer
# Processing record 470 of Set 1 | sibolga
# Processing record 471 of Set 1 | mitsuke
# Record not found
# Record not found
# Processing record 472 of Set 1 | emba
# Processing record 473 of Set 1 | taonan
# Processing record 474 of Set 1 | shubarshi
# Processing record 475 of Set 1 | porto santo
# Processing record 476 of Set 1 | tukrah
# Record not found
# Processing record 477 of Set 1 | paraiso
# Processing record 478 of Set 1 | jian
# Processing record 479 of Set 1 | babaeski
# Processing record 480 of Set 1 | kayerkan
# Processing record 481 of Set 1 | belluno
# Processing record 482 of Set 1 | yuxia
# Record not found
# Processing record 483 of Set 1 | mgandu
# Processing record 484 of Set 1 | gravdal
# Processing record 485 of Set 1 | kudahuvadhoo
# Processing record 486 of Set 1 | chuy
# Processing record 487 of Set 1 | ahipara
# Processing record 488 of Set 1 | garden city
# Processing record 489 of Set 1 | methoni
# Record not found
# Processing record 490 of Set 1 | mikhaylovka
# Processing record 491 of Set 1 | mount gambier
# Processing record 492 of Set 1 | colon
# Processing record 493 of Set 1 | husainabad
# Processing record 494 of Set 1 | jumla
# Processing record 495 of Set 1 | broken hill
# Processing record 496 of Set 1 | dombarovskiy
# Processing record 497 of Set 1 | fenoarivo
# Processing record 498 of Set 1 | areia branca
# Processing record 499 of Set 1 | lhokseumawe
# Processing record 500 of Set 1 | tashara
# Processing record 501 of Set 1 | abha
# Processing record 502 of Set 1 | hirara
# Processing record 503 of Set 1 | turan
# Processing record 504 of Set 1 | collie
# Processing record 505 of Set 1 | coxim
# Processing record 506 of Set 1 | timra
# Processing record 507 of Set 1 | codajas
# Processing record 508 of Set 1 | tombouctou
# Processing record 509 of Set 1 | catuday
# Processing record 510 of Set 1 | zhireken
# Processing record 511 of Set 1 | toora-khem
# Processing record 512 of Set 1 | pakruojis
# Processing record 513 of Set 1 | banjar
# Processing record 514 of Set 1 | fasa
# Processing record 515 of Set 1 | the valley
# Processing record 516 of Set 1 | soyo
# Processing record 517 of Set 1 | carmen
# Processing record 518 of Set 1 | shelopugino
# Processing record 519 of Set 1 | ghanzi
# Processing record 520 of Set 1 | pinega
# Processing record 521 of Set 1 | samana
# Processing record 522 of Set 1 | ocos
# Processing record 523 of Set 1 | lompoc
# Processing record 524 of Set 1 | pangkalanbuun
# Processing record 525 of Set 1 | timizart
# Processing record 526 of Set 1 | lazurne
# Processing record 527 of Set 1 | kaeo
# Processing record 528 of Set 1 | roseburg
# Processing record 529 of Set 1 | den helder
# Processing record 530 of Set 1 | mbandaka
# Processing record 531 of Set 1 | boksitogorsk
# Processing record 532 of Set 1 | sao gabriel da cachoeira
# Processing record 533 of Set 1 | lodwar
# Processing record 534 of Set 1 | assiniboia
# Processing record 535 of Set 1 | ulaanbaatar
# Processing record 536 of Set 1 | nouakchott
# Processing record 537 of Set 1 | fort nelson
# Processing record 538 of Set 1 | hervey bay
# Processing record 539 of Set 1 | birobidzhan
# Processing record 540 of Set 1 | mombetsu
# Processing record 541 of Set 1 | santa fe
# Processing record 542 of Set 1 | mareeba
# Processing record 543 of Set 1 | rupert
# Processing record 544 of Set 1 | sindor
# Processing record 545 of Set 1 | holland
# Processing record 546 of Set 1 | pacific grove
# Processing record 547 of Set 1 | chaparral
# Processing record 548 of Set 1 | pangnirtung
# Processing record 549 of Set 1 | williams lake
# Processing record 550 of Set 1 | vila do maio
# Processing record 551 of Set 1 | polur
# Processing record 552 of Set 1 | alice springs
# Record not found
# Processing record 553 of Set 1 | linxia
# Processing record 554 of Set 1 | kaputa
# Processing record 555 of Set 1 | kholmogory
# Processing record 556 of Set 1 | amboise
# Processing record 557 of Set 1 | gouyave
# Processing record 558 of Set 1 | guozhen
# Processing record 559 of Set 1 | sturgeon falls
# Processing record 560 of Set 1 | kupang
# Processing record 561 of Set 1 | hille
# Processing record 562 of Set 1 | zyryanskoye
# Processing record 563 of Set 1 | akhmeta
# Processing record 564 of Set 1 | lasa
# Processing record 565 of Set 1 | axim
# Processing record 566 of Set 1 | zeya
# I made it through the gauntlet. The message survived!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame


weather_dict = {"City": cityname,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#            City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Marsá Maţrūḩ   31.3525    27.2453     60.12        51           7
# 1       Kuching    1.5500   110.3333     80.38        88          59
# 2       Ushuaia  -54.8000   -68.3000     45.61        77          44
# 3    Natal'insk   56.4739    57.8698     -6.00        89          71
# 4      Szczecin   53.4289    14.5530     21.06        92          89
#
#    Wind Speed Country        Date
# 0       13.09      EG  1613098800
# 1        4.97      MY  1613098800
# 2        2.46      AR  1613098800
# 3        4.25      RU  1613098800
# 4        3.83      PL  1613098800

# %%
# Export the City_Data into a csv
weather_data.to_csv(r'..\output_data\my_weather_data.csv')
# Show Record Count
countforme = len(weather_data)
countforme
# Out:
# 566

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
# Save the figure
# Show plot
scatlat = weather_data["Latitude"]
scattemp = weather_data["Max Temp"]

plt.scatter(scatlat,scattemp)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('scatplotlatitudemaxtemp')
plt.show()

#This code is analyzing the max temperature of each city and latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
# Save the figure
# Show plot

#scatlat = weather_data["Latitude"]
scathum = weather_data["Humidity"]

plt.scatter(scatlat,scathum)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('scatplotlatitudehumidity')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
# Save the figure
# Show plot
#scatlat = weather_data["Latitude"]
scatcloud = weather_data["Cloudiness"]

plt.scatter(scatlat,scatcloud)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('scatplotlatitudecloudiness')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
# Save the figure
# Show plot

#scatlat = weather_data["Latitude"]
scatwindsp = weather_data["Wind Speed"]

plt.scatter(scatlat,scatwindsp)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('scatplotlatitudewindspeed')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
northlat_df = weather_data.loc[weather_data["Latitude"] >= 0,:]
southlat_df = weather_data.loc[weather_data["Latitude"] < 0,:]

northlat_df.head()
# Out:
#            City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Marsá Maţrūḩ   31.3525    27.2453     60.12        51           7
# 1       Kuching    1.5500   110.3333     80.38        88          59
# 3    Natal'insk   56.4739    57.8698     -6.00        89          71
# 4      Szczecin   53.4289    14.5530     21.06        92          89
# 5       Lincoln   40.8000   -96.6670      1.20        82          57
#
#    Wind Speed Country        Date
# 0       13.09      EG  1613098800
# 1        4.97      MY  1613098800
# 3        4.25      RU  1613098800
# 4        3.83      PL  1613098800
# 5       10.13      US  1613098800

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('northerntemplat')
# Out:
# The r-squared is: -0.8762095066879303

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('southerntemplat')

print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The r-squared is: 0.47865928323413937
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('northernhumlat')
# Out:
# The r-squared is: 0.43405451940875567

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('southernhumlat')

print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The r-squared is: 0.43702092392671316
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('northerncloudlat')
# Out:
# The r-squared is: 0.28814504761897375

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('southerncloudlat')
# Out:
# The r-squared is: 0.4170758932953789

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('northernwindlat')
# Out:
# The r-squared is: 0.11018463082617767

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('southernwindlat')
# Out:
# The r-squared is: -0.3417463608802612
